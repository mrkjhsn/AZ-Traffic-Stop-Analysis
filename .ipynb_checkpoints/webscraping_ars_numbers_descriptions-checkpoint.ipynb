# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = 'https://www.azleg.gov/arsDetail/?title=13'
html = requests.get(url).content
soup = BeautifulSoup(html, 'html.parser')

# %%
# iterate through ars numbers 
# pack them into a list
ars_number = []
for row in soup.find_all("a", {"class": "stat"}, text=True):
     ars_number.append(row.get_text())


# iterate through ars descriptions 
# pack them into a list
description = []
for row in soup.find_all("li", {"class": "colright"}, text=True):
    description.append(row.get_text())

# %%
# create dataframe from lists
ars_numbers_descriptions = pd.DataFrame({'ars_number': ars_number,
                          'ars_description': description})

# %%
ars_numbers_descriptions.shape
# Out:
# (943, 2)

# %%
ars_numbers_descriptions.head(30)
# Out:
#    ars_number                                    ars_description
# 0      13-101                                           Purposes
# 1   13-101.01           Additional purposes of the criminal law
# 2      13-102                             Applicability of title
# 3      13-103   Abolition of common law offenses and affirmat...
# 4      13-104                               Rule of construction
# 5      13-105                                        Definitions
# 6      13-106   Death of convicted defendant; dismissal of ap...
# 7      13-107                                   Time limitations
# 8      13-108                          Territorial applicability
# 9      13-109                                     Place of trial
# 10     13-110   Conviction for attempt although crime perpetr...
# 11     13-111   Former jeopardy or acquittal as bar to same o...
# 12     13-113   Conviction or acquittal in one county as bar ...
# 13     13-114   Speedy trial; counsel; witnesses and confront...
# 14     13-115   Presumption of innocence and benefit of doubt...
# 15     13-116                                  Double punishment
# 16     13-117   Defendant as witness; no comment on failure t...
# 17     13-118   Sexual motivation special allegation; procedu...
# 18     13-120   Disposition of property taken from defendant;...
# 19     13-121   Jurisdiction of the court in proceedings subs...
# 20     13-122               Action for recovery of public monies
# 21     13-123           Certificate of special public importance
# 22     13-201                Requirements for criminal liability
# 23     13-202   Construction of statutes with respect to culp...
# 24     13-203   Causal relationship between conduct and resul...
# 25     13-204   Effect of ignorance or mistake upon criminal ...
# 26     13-205   Affirmative defenses; justification; burden o...
# 27     13-206                                         Entrapment
# 28     13-301                           Definition of accomplice
# 29     13-302              Criminal liability based upon conduct
